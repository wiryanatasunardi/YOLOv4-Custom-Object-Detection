# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/yolo_custom_model_training'
# Out:
# custom_data  darknet

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolo_custom_model_training/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo_custom_model_training/darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.02 MiB | 4.92 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_training/darknet
# Out:
# /content/drive/MyDrive/yolo_custom_model_training/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_training
# Out:
# /content/drive/MyDrive/yolo_custom_model_training

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov4-tiny.cfg custom_weight/yolov4-tiny.conv.29 -dont_show -map
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.857864), count: 3, class_loss = 0.000012, iou_loss = 0.307663, total_loss = 0.307675
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.843455), count: 5, class_loss = 0.022692, iou_loss = 3.306010, total_loss = 3.328702
#  total_bbox = 445895, rewritten_bbox = 0.000224 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.857123), count: 3, class_loss = 0.087833, iou_loss = 0.302857, total_loss = 0.390690
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.802382), count: 4, class_loss = 0.696059, iou_loss = 2.131658, total_loss = 2.827716
#  total_bbox = 445902, rewritten_bbox = 0.000224 %
# ...
